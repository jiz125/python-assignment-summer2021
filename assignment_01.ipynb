# %%
#Example

a = "Stray Bird"
b = "by Rabindranath Tagore | 1916"

print (f'{a}')
print('\n')
print(b.upper())
print('\n')
print('Stray birds of summer come to my window to sing and fly away. And yellow leaves of autumn, which have no songs, flutter and fall there with a sigh')
print('\n')
print('O troupe of little vagrants of the world, leave your footprints in my words.')
print('\n')
print("The world puts off its mask of vastness to its lover.")
print("It becomes small as one song, as one kiss of the eternal.")
print('\n')
print("It is the tears of the earth that keep her smiles in bloom.")
print('\n')
print("The mighty desert is burning for the love of a blade of grass who shakes her head and laughs and flies away.")
print('\n')
print("If you shed tears when you miss the sun, you also miss the stars.")
print('\n')
print("The sands in your way beg for your song and your movement, dancing water. Will you carry the burden of their lameness?")
print('\n')
print("Her wistful face haunts my dreams like the rain at night.")
print('\n')
print("Once we dreamt that we were strangers.")
print('\n')
print("We wake up to find that we were dear to each other.")
print('\n')
print("Sorrow is hushed into peace in my heart like the evening among the silent trees.")
print('\n')
print("Some unseen fingers, like idle breeze, are playing upon my heart the music of the ripples")
print('\n')
print("What language is thine, O sea?")
print("The language of eternal question.")
print("What language is thy answer, O sky?")
print("The language of eternal silence.")
print('\n')
print("Listen, my heart, to the whispers of the world with which it makes love to you.")
print('\n')
print (f'{a}')
print (f'{a}')
print (f'{a}.')
# Out:
# Stray Bird
#
#
# BY RABINDRANATH TAGORE | 1916
#
#
# Stray birds of summer come to my window to sing and fly away. And yellow leaves of autumn, which have no songs, flutter and fall there with a sigh
#
#
# O troupe of little vagrants of the world, leave your footprints in my words.
#
#
# The world puts off its mask of vastness to its lover.
# It becomes small as one song, as one kiss of the eternal.
#
#
# It is the tears of the earth that keep her smiles in bloom.
#
#
# The mighty desert is burning for the love of a blade of grass who shakes her head and laughs and flies away.
#
#
# If you shed tears when you miss the sun, you also miss the stars.
#
#
# The sands in your way beg for your song and your movement, dancing water. Will you carry the burden of their lameness?
#
#
# Her wistful face haunts my dreams like the rain at night.
#
#
# Once we dreamt that we were strangers.
#
#
# We wake up to find that we were dear to each other.
#
#
# ...
